# %% [markdown]
# # This is the pipeline for the Assignment

# %% [markdown]
# Functions are all defined in the *Utilities.py* file
#
# The analysis is done in the *Main.py* file
#
# This Jupyter notebook page is used to display the graphs and collect user input.

# %%
import pandas as pd
from pathlib import Path
import Utilities as ut

lpi_short = pd.read_csv("LivingPlanet.csv")
lpi_short
# Out:
#      Entity      Code  Year  Living Planet Index    Upper CI    Lower CI
# 0    Africa       NaN  1970           100.000000  100.000000  100.000000
# 1    Africa       NaN  1971            95.461970  104.910800   87.790567
# 2    Africa       NaN  1972            94.683415  110.867830   81.479840
# 3    Africa       NaN  1973            99.181175  120.870720   81.908750
# 4    Africa       NaN  1974            99.384934  127.877780   77.144610
# ..      ...       ...   ...                  ...         ...         ...
# 337   World  OWID_WRL  2014            31.669020   38.071987   26.383457
# 338   World  OWID_WRL  2015            31.627533   38.068720   26.281210
# 339   World  OWID_WRL  2016            31.145410   37.562138   25.770210
# 340   World  OWID_WRL  2017            30.885270   37.343040   25.465453
# 341   World  OWID_WRL  2018            30.897567   37.437810   25.400314
#
# [342 rows x 6 columns]

# %%
lpi_long = pd.read_csv("LPD2022_public/LPD2022_public.csv")
lpi_long
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 lpi_long = pd.read_csv("LPD2022_public/LPD2022_public.csv")
#       2 lpi_long
#
# File c:\Users\Andrea\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
from Main import *
main()
# Out:
# Welcome to the Norwegian wetland info generator :)
# What info do you want to be displayed?
# Statistics (S)
# Graph (G)
# Hello Message (H)
# Press Q for quit
# Statistics (S)
# Graph (G)
# Hello Message (H)
# Press Q for quit
# This is some statistics:
# Statistics (S)
# Graph (G)
# Hello Message (H)
# Press Q for quit
# You wanted a hello message:)
# Statistics (S)
# Graph (G)
# Hello Message (H)
# Press Q for quit
# This stops the generator and returns a graph:
# alt.Chart(...)
